# %%
res = requests.get(r"https://pipeline2.kindermorgan.com/Capacity/OpAvailPoint.aspx?code=NGPL")

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
from time import sleep
from selenium.webdriver.common.keys import Keys

# %%
from datetime import date,timedelta

# %%
driver = webdriver.Chrome()

driver.implicitly_wait(5)

driver.get(r"https://pipeline2.kindermorgan.com/Capacity/OpAvailPoint.aspx?code=NGPL")



datetoday=date.today()
Jan012025=date.fromisoformat(r"2025-01-01")
deltaDay= timedelta(days=1)

curdate = Jan012025

while curdate<= datetoday:
    # datel.clear()
    sleep(5)
    datel = driver.find_element(By.CSS_SELECTOR,"input.bodytext.igte_NautilusEditInContainer")
    elem = driver.find_element(By.ID, 'WebSplitter1_tmpl1_ContentPlaceHolder1_HeaderBTN1_btnDownload')

    print("clicking the date changer")
    datel.click()
    print("breathing space")
    datel.send_keys(Keys.BACK_SPACE)
    datel.send_keys(Keys.BACK_SPACE)
    datel.send_keys(Keys.BACK_SPACE)
    datel.send_keys(Keys.BACK_SPACE)
    datel.send_keys(Keys.BACK_SPACE)
    datel.send_keys(Keys.BACK_SPACE)
    datel.send_keys(Keys.BACK_SPACE)
    datel.send_keys(Keys.BACK_SPACE)
    datel.send_keys(Keys.BACK_SPACE)
    datel.send_keys(Keys.BACK_SPACE)
    print(f"enternig {curdate.strftime(r"%m%d%Y")}")
    datel.send_keys(curdate.strftime(r"%m%d%Y"))

    datel.send_keys(Keys.RETURN)


    sleep(3)

    elem.click()
    print(f"download clicked for {curdate}")
    curdate+=deltaDay
    sleep(5)
    print("refreshing the page")
    try:
        driver.refresh()
    except Exception as e:
        print(e)
    
    
print("quitting")
driver.quit()
# Out:
# clicking the date changer
# breathing space
# enternig 01012025
# download clicked for 2025-01-01
# refreshing the page
# clicking the date changer
# breathing space
# enternig 01022025
# download clicked for 2025-01-02
# refreshing the page
# clicking the date changer
# breathing space
# enternig 01032025
# download clicked for 2025-01-03
# refreshing the page
# clicking the date changer
# breathing space
# enternig 01042025
# download clicked for 2025-01-04
# refreshing the page
# clicking the date changer
# breathing space
# enternig 01052025
# download clicked for 2025-01-05
# refreshing the page
# clicking the date changer
# breathing space
# enternig 01062025
# download clicked for 2025-01-06
# refreshing the page
# clicking the date changer
# breathing space
# enternig 01072025
# download clicked for 2025-01-07
# refreshing the page
# clicking the date changer
# breathing space
# enternig 01082025
# download clicked for 2025-01-08
# refreshing the page
# ...

# %%
import os

# %%
basePath=os.path.abspath(r"../../ArchiveFiles")

# %%
import pandas as pd
import datetime

# %%
filenames= dict()

# %%
for f in os.listdir(basePath):
    df= pd.read_excel(os.path.join(basePath,f),nrows=2,dtype=str)
    filenames[f]=datetime.datetime.strptime(df.loc[0,"Eff Gas Day/Eff Time"].split(" ")[0], r"%m/%d/%Y").date().strftime("%m%d%Y") + ".xlsx"

# %%
filenames
# Out:
# {'OpAvailExportedData (76).xlsx': '03182025.xlsx',
#  'OpAvailExportedData (33).xlsx': '02032025.xlsx',
#  'OpAvailExportedData (52).xlsx': '02222025.xlsx',
#  'OpAvailExportedData (17).xlsx': '01182025.xlsx',
#  'OpAvailExportedData (28).xlsx': '01292025.xlsx',
#  'OpAvailExportedData (50).xlsx': '02202025.xlsx',
#  'OpAvailExportedData (15).xlsx': '01162025.xlsx',
#  'OpAvailExportedData (74).xlsx': '03162025.xlsx',
#  'OpAvailExportedData (31).xlsx': '02012025.xlsx',
#  'OpAvailExportedData (49).xlsx': '02192025.xlsx',
#  'OpAvailExportedData (70).xlsx': '03122025.xlsx',
#  'OpAvailExportedData (35).xlsx': '02052025.xlsx',
#  'OpAvailExportedData (8).xlsx': '01092025.xlsx',
#  'OpAvailExportedData (69).xlsx': '03112025.xlsx',
#  'OpAvailExportedData (54).xlsx': '02242025.xlsx',
#  'OpAvailExportedData (11).xlsx': '01122025.xlsx',
#  'OpAvailExportedData (56).xlsx': '02262025.xlsx',
#  'OpAvailExportedData (13).xlsx': '01142025.xlsx',
# ...

# %%
from pathlib import Path

# %%
dest=Path(r"../../Renamed")

# %%
Path(basePath) / "OpAvailExportedData (76).xlsx"
# Out:
# PosixPath('/Users/saijagadeeshyadavalli/Documents/Programming/Webscraping/Particles/PipeScrape/ArchiveFiles/OpAvailExportedData (76).xlsx')

# %%
for i in filenames.keys():
    src= Path(basePath) / i
    targetName = dest / filenames[i]
    src.rename(targetName)

# %%
a

def copy_and_rename_pathlib(src_path, dest_path, new_name):
	# Create Path objects
	src_path = Path(src_path)
	dest_path = Path(dest_path)

	# Copy and rename the file
	new_path = dest_path / new_name
	src_path.rename(new_path)

# %%
df= pd.read_excel(r"/Users/saijagadeeshyadavalli/Documents/Programming/Webscraping/Particles/PipeScrape/ArchiveFiles/OpAvailExportedData (76).xlsx",nrows=2,dtype=str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TSP                   1 non-null      object
#  1   TSP Name              1 non-null      object
#  2   Eff Gas Day/Eff Time  1 non-null      object
#  3   CycleDesc             1 non-null      object
#  4   Loc Purp Desc         1 non-null      object
#  5   Meas Basis Desc       1 non-null      object
#  6   Post Date/Post Time   1 non-null      object
#  7   Loc/QTI Desc          1 non-null      object
# dtypes: object(8)
# memory usage: 196.0+ bytes

# %%
import datetime

# %%
somedate=datetime.datetime.strptime(df.loc[0,"Eff Gas Day/Eff Time"].split(" ")[0], r"%m/%d/%Y").date()

# %%
somedate.strftime("%m%d%Y")
# Out:
# '03182025'

# %%
df.loc[0,"Eff Gas Day/Eff Time"].split(" ")[0]
# Out:
# '3/18/2025'
